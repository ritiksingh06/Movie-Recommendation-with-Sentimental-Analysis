# %%
import pandas as pd
import numpy as np

# %%
main=pd.read_csv("datasets/main_data.csv")

# %%
main
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6004       Craig Brewer     Eddie Murphy   Jermaine Fowler
# 6005    Joseph Kosinski       Tom Cruise      Miles Teller
# 6006      Joel Crawford     Nicolas Cage        Emma Stone
# 6007       Ridley Scott       Matt Damon       Adam Driver
# 6008    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
main.columns
# Out:
# Index(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
main["Words"]=main["genres"]+" "+main["director_name"]+" "+main["actor_1_name"]+" "+main["actor_2_name"]+" "+main["actor_3_name"]
main.head(5)
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
main["Words"][0]
# Out:
# 'Action Adventure Fantasy Sci-Fi James Cameron CCH Pounder Joel David Moore Wes Studi'

# %%
li=["director_name","actor_1_name","actor_2_name","actor_2_name","actor_3_name","genres","comb"]
main.drop(li,axis=1,inplace=True)

# %%
main.head(5)
# Out:
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                Words
# 0  Action Adventure Fantasy Sci-Fi James Cameron ...
# 1  Action Adventure Fantasy Gore Verbinski Johnny...
# 2  Action Adventure Thriller Sam Mendes Christoph...
# 3  Action Thriller Christopher Nolan Tom Hardy Ch...
# 4  Documentary Doug Walker Doug Walker Rob Walker...

# %%
main.to_csv("datasets/Modified_main_data.csv",index=False)
