# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import pickle

# %%
file=pd.read_csv("Modified_main_data.csv")
ri_model=pickle.load(open("nlp_model.pkl","rb"))
vectorizer=pickle.load(open("tranform.pkl","rb"))
file.set_index("movie_title",inplace=True)
data=pd.read_csv("main_data.csv")
data.set_index("movie_title",inplace=True)

# %%
count=CountVectorizer()
c_marix=count.fit_transform(file["Words"])
indexs=pd.Series(file.index)

# %%
cos_similarity=cosine_similarity(c_marix,c_marix)
cos_similarity
# Out:
# array([[1.        , 0.24174689, 0.16116459, ..., 0.16116459, 0.        ,
#         0.        ],
#        [0.24174689, 1.        , 0.18181818, ..., 0.09090909, 0.        ,
#         0.        ],
#        [0.16116459, 0.18181818, 1.        , ..., 0.09090909, 0.        ,
#         0.        ],
#        ...,
#        [0.16116459, 0.09090909, 0.09090909, ..., 1.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 1.        ,
#         0.10540926],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.10540926,
#         1.        ]])

# %%
def recommend(movie,cos_similarity=cos_similarity):
    recommend_movie=[]
    ind=indexs[indexs==movie].index[0]
    similar=pd.Series(cos_similarity[ind]).sort_values(ascending=False)
    top_20_similar=list(similar.iloc[1:21].index)
    for i in top_20_similar:
        recommend_movie.append(list(file.index)[i])
    return recommend_movie,top_20_similar

# %%
def rec_from_rev(arr):
    recommend=[]
    movie_review=np.array(arr)
    movie_vector=vectorizer.transform(movie_review)
    prediction=ri_model.predict(movie_vector)
    for i in range(len(prediction)):
        if prediction[i]==1:
            recommend.append(arr[i])
    return recommend

# %%
rec,inde=recommend("the tax collector")

# %%
recommend=rec_from_rev(rec)

# %%
movie_detail=data.loc[recommend,:]
movie_detail
# Out:
#                                       director_name       actor_1_name  \
# movie_title
# harsh times                              David Ayer       J.K. Simmons
# sabotage                                 David Ayer      Mireille Enos
# a most violent year                    J.C. Chandor      David Oyelowo
# end of watch                             David Ayer    Jake Gyllenhaal
# contraband                        Baltasar Kormákur       J.K. Simmons
# 16 blocks                            Richard Donner       Bruce Willis
# snakes on a plane                    David R. Ellis          Lin Shaye
# faster                           George Tillman Jr.     Dwayne Johnson
# lone wolf mcquade                      Steve Carver    David Carradine
# confessions of a dangerous mind      George Clooney         Dick Clark
# mean streets                        Martin Scorsese     Robert De Niro
# bullitt county                      David McCracken     Mike C. Nelson
# n-secure                          David M. Matthews     Essence Atkins
# brick mansions                    Camille Delamarre        Paul Walker
# dum maaro dum                           Rohan Sippy  Abhishek Bachchan
# dead man's shoes                      Shane Meadows    Paddy Considine
# the player                                  unknown      Nick Wechsler
#
#                                        actor_2_name      actor_3_name  \
# movie_title
# harsh times                          Christian Bale     Noel Gugliemi
# sabotage                             Martin Donovan    Maurice Compte
# a most violent year                 Ashley Williams     Albert Brooks
# end of watch                          Anna Kendrick   America Ferrera
# contraband                             David O'Hara        Lukas Haas
# 16 blocks                               David Zayas        Sasha Roiz
# snakes on a plane                    Kenan Thompson  Rachel Blanchard
# faster                                 Tom Berenger         Mike Epps
# lone wolf mcquade                 William Sanderson    Robert Beltran
# confessions of a dangerous mind  David Julian Hirsh     Jennifer Hall
# mean streets                        David Carradine      David Proval
# bullitt county                         Jenni Melear   David McCracken
# n-secure                              Lamman Rucker  Tempestt Bledsoe
# brick mansions                       Robert Maillet               RZA
# dum maaro dum                          Bipasha Basu           Prateik
# dead man's shoes                       Gary Stretch     George Newton
# the player                        Philip Winchester       Jeff Marlow
#
#                                                                         genres  \
# movie_title
# harsh times                                        Action Crime Drama Thriller
# sabotage                                           Action Crime Drama Thriller
# a most violent year                                Action Crime Drama Thriller
# end of watch                                              Crime Drama Thriller
# contraband                                         Action Crime Drama Thriller
# 16 blocks                                          Action Crime Drama Thriller
# snakes on a plane                        Action Adventure Crime Drama Thriller
# faster                                             Action Crime Drama Thriller
# lone wolf mcquade                          Action Crime Drama Thriller Western
# confessions of a dangerous mind  Biography Comedy Crime Drama Romance Thriller
# mean streets                                      Crime Drama Romance Thriller
# bullitt county                                           Action Drama Thriller
# n-secure                                                  Crime Drama Thriller
# brick mansions                                     Action Crime Drama Thriller
# dum maaro dum                                      Action Crime Drama Thriller
# dead man's shoes                                          Crime Drama Thriller
# the player                                         Action Crime Drama Thriller
#
#                                                                               comb
# movie_title
# harsh times                      J.K. Simmons Christian Bale Noel Gugliemi Davi...
# sabotage                         Mireille Enos Martin Donovan Maurice Compte Da...
# a most violent year              David Oyelowo Ashley Williams Albert Brooks J....
# end of watch                     Jake Gyllenhaal Anna Kendrick America Ferrera ...
# contraband                       J.K. Simmons David O'Hara Lukas Haas Baltasar ...
# 16 blocks                        Bruce Willis David Zayas Sasha Roiz Richard Do...
# snakes on a plane                Lin Shaye Kenan Thompson Rachel Blanchard Davi...
# faster                           Dwayne Johnson Tom Berenger Mike Epps George T...
# lone wolf mcquade                David Carradine William Sanderson Robert Beltr...
# confessions of a dangerous mind  Dick Clark David Julian Hirsh Jennifer Hall Ge...
# mean streets                     Robert De Niro David Carradine David Proval Ma...
# bullitt county                   Mike C. Nelson Jenni Melear David McCracken Da...
# n-secure                         Essence Atkins Lamman Rucker Tempestt Bledsoe ...
# brick mansions                   Paul Walker Robert Maillet RZA Camille Delamar...
# dum maaro dum                    Abhishek Bachchan Bipasha Basu Prateik Rohan S...
# dead man's shoes                 Paddy Considine Gary Stretch George Newton Sha...
# the player                       Nick Wechsler Philip Winchester Jeff Marlow un...
